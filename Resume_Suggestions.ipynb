# %%
import os

from langchain.chains import ConversationChain
from langchain_core.messages import SystemMessage
from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate
from langchain.memory import ConversationBufferWindowMemory
from langchain_openai import ChatOpenAI

# %%
OPENAI_API_KEY = "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"
os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY
model_name = "gpt-4o-mini-2024-07-18"

# %%
template_content = """You are a helpful assistant. You do not respond as 'User' or pretend to be 'User'. You only 
respond once as 'assistant'. 

System Role: Resume Coach

Your role is to act as a resume coach. You will assist users in improving their resumes to better align with specific 
job descriptions. Provide professional advice on resume building, interview preparation, and career development. 
Offer constructive feedback and encouragement. Whenever you are given a resume and a job description, there will be 
tokens added before and after the resume and job description. The tokens are as follows: <RESUME STARTS HERE> and 
<RESUME ENDS HERE> for the resume and <JOB DESCRIPTION STARTS HERE> and <JOB DESCRIPTION ENDS HERE> for the job 
description. Utilize these tokens to provide feedback and suggestions and clearly segregate the resume and job
description. Do not mix up the content of the resume and job description. In case the resume or job requirements 
in the description do not align with each other, do not mix up the content of the resume and job description and 
keep them separate and process them accordingly. Provide feedback based only on the content provided.
"""

resume_analysis_prompt = "Provide a detailed summary of the candidate's skills, experience, and qualifications based on the content of the following resume: <RESUME STARTS HERE> {}. <RESUME ENDS HERE>"
job_description_analysis_prompt = "List the key skills, qualifications, and experience required as outlined in the following job description: <JOB DESCRIPTION STARTS HERE> {}. <JOB DESCRIPTION ENDS HERE>"
comparison_prompt = "Compare the resume: <RESUME STARTS HERE> {}. <RESUME ENDS HERE> with the job description: <JOB DESCRIPTION STARTS HERE> {}.<JOB DESCRIPTION ENDS HERE> Do they match? If not, what are the gaps? Do not make any assumptions about the candidate's skills or experience or the job requirements."
gap_analysis_prompt = "Compare the skills and experience detailed in this resume: <RESUME STARTS HERE> {} <RESUME ENDS HERE> with the requirements listed in the job description: <JOB DESCRIPTION STARTS HERE> {}. <JOB DESCRIPTION ENDS HERE> Identify any gaps or mismatches and list them out specificly. Please provide examples on how to fulfill those gaps."
experience_enhancement_prompt = "Based on the candidate's experience outlined in this resume: <RESUME STARTS HERE> {} <RESUME ENDS HERE>, recommend practical activities or steps to gain or improve the experience aligned with the needs of this role: <JOB DESCRIPTION STARTS HERE> {}. <JOB DESCRIPTION ENDS HERE>. Include recommendations for additional qualifications or certifications."
resume_formatting_prompt = "Offer guidance on how the candidate can enhance the formatting of their resume: <RESUME STARTS HERE> {} <RESUME ENDS HERE> to improve visual appeal and readability."
resume_length_prompt = "Recommend strategies for the candidate to adjust the length of their resume: <RESUME STARTS HERE> {} <RESUME ENDS HERE>, ensuring it is concise while remaining aligned with the requirements in the job description: <JOB DESCRIPTION STARTS HERE> {}. <JOB DESCRIPTION ENDS HERE>"

# %%
def generate_llm_response(prompt_input):
    output = resume_chain.predict(input=prompt_input)
    return output

# %%
system_message = SystemMessage(content=template_content)
human_message = HumanMessagePromptTemplate.from_template("{history} User:{input} Assistant:")

prompt_template = ChatPromptTemplate(messages=[system_message, human_message], validate_template=True)

memory = ConversationBufferWindowMemory(k=3)

# %% [markdown]
# ### Chain of Thought(COT) Prompting

# %%
cot_chain = ConversationChain(
        llm=ChatOpenAI(temperature=0.0, model="gpt-3.5-turbo-1106"),
        verbose=False
)

# %% [markdown]
# <hr>

# %% [markdown]
# ### Resume Analysis

# %%
llm = ChatOpenAI(temperature=0.0, model=model_name)

# %%
resume_chain = ConversationChain(
        llm=llm,
        prompt=prompt_template,
        memory=memory,
        verbose=False
)

# %%
resume_content = """
senior data scientist  \nexample by resume genius  \nchicago, il  •  your.email @email.com •  ( 312) 875-3382  
\n \naccomplished senior data scientist with 10+ years of experience driving innovative solutions and delivering 
\nactionable insights. expertise in machine learning, statistical modeling, and big data analytics. 
proven track record of \nleading cross -functional te ams and implementing data -driven strategies that have 
generated $50m+ in revenue.  \nprofessional experience  \n \nsenior data scientist  \nhargrove tech , chicago, 
il  \naugust 20 xx–present  \n lead a team of 8 data scientists in developing and implementing advanced machine 
learning models, resulting \nin a 25% increase in predictive accuracy  \n spearheaded a company -wide initiative
to optimize data pipelines, reducing processing time by 40% and \nsaving $1.2m annually  \n collaborate with
cross -functional teams to develop data -driven strategies, contributing to a 15% increase in \noverall revenue 
\nlead data scientist  \nsuntrust analytics , chicago, il  \njuly 20 xx–august 20 xx \n developed and deployed 
a real -time fraud detection system using ensemble learning techniques, saving the \ncompany $3.5m in potential 
losses  \n built and maintained a customer segmentation model using clustering algorithms, resulting in a 20% 
increase \nin targeted marketing roi  \n conducted regular workshops and training sessions on advanced 
data science techniques, upskilling the team \nand improving overall performance by 30%  \ndata analyst  
\nmaverick solutions, new york, ny  \njuly 20 xx–august 20 xx \n analyzed large datasets using sql and 
python, providing actionable insights to business stakeholders  \n developed and maintained etl processes, 
ensuring timely and accurate data integration from multiple \nsources  \n created ad -hoc reports and analyses, 
contributing to data -driven decision making  \neducation  \n \nnew york university , new york, ny  \nms in data science  \nmay 20xx  \nadditional skills  \n \n● machine learning:  supervised learning, unsupervised learning, deep learning, neural networks, \nensemble methods, natural language processing (nlp)  \n● statistical modeling:  regression analysis, time series analysis, bayesian inference, hypothesis \ntesting, experimental design  \n● programming languages:  python, r, sql, java, scala  \n \n  \n \ndear job seeker,  \n \nif you’re looking for a classy resume template, you can’t do any better than \nthe “milano”. its simple elegance is just what you need if you want to imbue \nyour resume with a balance of professionalism and good taste — plus a \ndash of creativity.  \n \neverything on the milano is left -aligned, which helps the hiring manager \nquickly look through your resume by simply scanning down the page to \nidentify relevant experience and skills.  \n \nif you’re still struggling to write your resume, here are some free resources \nto help you put together a resume that shows employers you’re the right \nperson for the job:  \n \n·     free resume builder  \n·     how to write a resume  \n·     resume samples by industry  \n \nonce you have a great resume, pair it with a convincing cover letter using \nour matching  2022 cover letter template . here are a few resources to help \nyou write a cover letter that gives your application the boost it needs to \nland you an interview:  \n·     cover letter builder  \n·     how to write a cover letter  \n·     cover letter examples by industry  \n \n \n \nbest regards,  \n \n \n \n \n \n \n \nimportant:  to delete the second page, right -click on the page and click “delete rows”
"""

# %%
job_description_content="""
what do we do? \n\nwe are the simulation and analytics team within volvo group trucks technology, a dynamic team working towards enabling the technology organization in evaluating futuristic products and services for volvo business units such as trucks, buses, construction equipment and marine\n\nthe main tasks in our team are to meet our customer’s expectation on quality, fuel consumption and to comply with emission legislation. this is done by selecting engine hw-components and calibrate engine related functions. upcoming emission legislation requires development of advanced control strategies together with an optimized hardware and software. you will be an important contributor in this development. powertrain is the heart of the truck and is one of the focus areas within volvo group, which is at the forefront of sustainable transport solutions for tomorrow.\n\nwhat will you do? \nyou will work in agile teams through good collaboration with our colleagues in software development and design teams all around the world.\n\nyou along with the team will be responsible for understanding customer usage and performance of our products and for providing our solutions throughout entire product life cycle, from idea investigation and concept evaluation to industrialization and to aftermarket and maintenance. you will make meaningful interpretations, recommendations and eventually predictions from the data available from various sources to support our endeavor in moving towards data driven powertrain development\n\nyou get the opportunity to follow your data driven models from script to test cell to verification in a truck and eventually to being used by our end customers.\n\nwe have an agile way of working, where each team plan their activities in sprints and deliver solutions together as a team. we strive to have an open and honest environment within the teams, where it is easy to ask each other for support when needed. the tasks can be either part of a larger project or short tasks to improve products currently in production.\n\nyou will get the opportunity to interact with highly committed colleagues from different cultures. we hope you will learn as much from us as we will from you.\n\n who are you? \n\nwe believe that to be successful in this position, you are a team player, have strong experience in data engineering and analysis area, and a will to deliver. you have a knowledge of control systems and feedback systems (closed loop) in general with an exposure to numerical and data driven simulation of a system. you must have a proven experience in data modelling – regression, clustering, neural networks, time series etc. and should have used them in solving real-life challenges (prediction, automation, real time optimization etc).\n\nyou have a willingness to learn and take more responsibility with can-do attitude.\n\nyou will be greatly appreciated in this role if you have demonstrated predictive analysis and decision-making using data.\n\nif you are a master’s degree holder in mechanical/automobile/electronics/mechatronics engineering with fantastic analytical skills, have gained a strong domain understanding in powertrain engineering with proven skills in handling and analysing large set of data to make meaningful interpretations and if you believe that you can work smoothly with python ( including libraries like numpy, scipy, pandas, tensorflow) , r, sql, git, azure, hadoop and matlab/simulink, pyspark, c/c++/ scala then you can be a good fit into this role.\n\nexperience of working with relational databases, data privacy and understanding of iot based instrumentation design with additional data logging to build or validate models is a big plus.\n\na passion for turning data into knowledge with great visualizations using power bi, qlikview, tableau and an experience of working with plant/ component models, and integration of these models into sil/mil/hil evaluations would be an icing on the cake.
"""

# %% [markdown]
# ### 1. Resume Analysis

# %%
prompt_input = resume_analysis_prompt.format(resume_content, job_description_content)
output = resume_chain.predict(input=prompt_input)
print(output)
# Out:
# **Candidate Summary:**
#
# **Name:** Senior Data Scientist
# **Location:** Chicago, IL
# **Contact:** your.email@email.com | (312) 875-3382
#
# **Professional Overview:**
# The candidate is an accomplished Senior Data Scientist with over 10 years of experience in the field. They have a strong background in driving innovative solutions and delivering actionable insights through expertise in machine learning, statistical modeling, and big data analytics. The candidate has a proven track record of leading cross-functional teams and implementing data-driven strategies that have generated over $50 million in revenue.
#
# **Professional Experience:**
#
# 1. **Senior Data Scientist at Hargrove Tech (August 20xx – Present)**
#    - Leads a team of 8 data scientists in developing and implementing advanced machine learning models, achieving a 25% increase in predictive accuracy.
#    - Spearheaded a company-wide initiative to optimize data pipelines, resulting in a 40% reduction in processing time and annual savings of $1.2 million.
#    - Collaborates with cross-functional teams to develop data-driven strategies, contributing to a 15% increase in overall revenue.
#
# 2. **Lead Data Scientist at SunTrust Analytics (July 20xx – August 20xx)**
#    - Developed and deployed a real-time fraud detection system using ensemble learning techniques, saving the company $3.5 million in potential losses.
#    - Built and maintained a customer segmentation model using clustering algorithms, leading to a 20% increase in targeted marketing ROI.
#    - Conducted workshops and training sessions on advanced data science techniques, enhancing team performance by 30%.
#
# 3. **Data Analyst at Maverick Solutions (July 20xx – August 20xx)**
#    - Analyzed large datasets using SQL and Python, providing actionable insights to business stakeholders.
#    - Developed and maintained ETL processes for timely and accurate data integration from multiple sources.
#    - Created ad-hoc reports and analyses to support data-driven decision-making.
#
# **Education:**
# - **MS in Data Science, New York University (May 20xx)**
#
# **Technical Skills:**
# - **Machine Learning:** Supervised learning, unsupervised learning, deep learning, neural networks, ensemble methods, natural language processing (NLP).
# - **Statistical Modeling:** Regression analysis, time series analysis, Bayesian inference, hypothesis testing, experimental design.
# - **Programming Languages:** Python, R, SQL, Java, Scala.
#
# **Summary of Strengths:**
# - Strong leadership and team management skills.
# - Proven ability to drive revenue growth through data-driven strategies.
# - Expertise in advanced machine learning and statistical modeling techniques.
# - Proficient in multiple programming languages and data analysis tools.
# - Experience in training and upskilling teams to enhance performance.
#
# Overall, the candidate presents a robust profile with significant experience and a strong skill set that aligns well with advanced data science roles.

# %% [markdown]
# ### 2. Job Description Analysis

# %%
prompt_input = job_description_analysis_prompt.format(resume_content, job_description_content)
output = resume_chain.predict(input=prompt_input)
print(output)
# Out:
# **Key Skills, Qualifications, and Experience Required:**
#
# **Position:** Senior Data Scientist
# **Location:** Chicago, IL
#
# **Experience:**
# - 10+ years of experience in data science, specifically in driving innovative solutions and delivering actionable insights.
# - Proven track record of leading cross-functional teams and implementing data-driven strategies that have generated over $50 million in revenue.
#
# **Professional Experience:**
# 1. **Senior Data Scientist:**
#    - Experience in leading a team of data scientists to develop and implement advanced machine learning models, with a focus on improving predictive accuracy.
#    - Ability to spearhead initiatives to optimize data pipelines, resulting in significant reductions in processing time and cost savings.
#    - Collaboration with cross-functional teams to develop data-driven strategies that contribute to revenue growth.
#
# 2. **Lead Data Scientist:**
#    - Experience in developing and deploying real-time fraud detection systems using ensemble learning techniques.
#    - Proven ability to build and maintain customer segmentation models using clustering algorithms to enhance marketing ROI.
#    - Experience in conducting workshops and training sessions to upskill team members and improve overall performance.
#
# 3. **Data Analyst:**
#    - Proficiency in analyzing large datasets using SQL and Python to provide actionable insights to business stakeholders.
#    - Experience in developing and maintaining ETL processes for accurate data integration from multiple sources.
#    - Ability to create ad-hoc reports and analyses to support data-driven decision-making.
#
# **Education:**
# - Master’s degree in Data Science from a recognized institution (e.g., New York University).
#
# **Technical Skills:**
# - **Machine Learning:** Expertise in supervised learning, unsupervised learning, deep learning, neural networks, ensemble methods, and natural language processing (NLP).
# - **Statistical Modeling:** Proficient in regression analysis, time series analysis, Bayesian inference, hypothesis testing, and experimental design.
# - **Programming Languages:** Proficient in Python, R, SQL, Java, and Scala.
#
# Overall, the job description emphasizes the need for extensive experience in data science, strong leadership capabilities, technical proficiency in machine learning and statistical modeling, and the ability to drive business results through data-driven strategies.

# %% [markdown]
# ### 3. Resume Comparison with JD

# %%
prompt_input = comparison_prompt.format(resume_content, job_description_content)
output = resume_chain.predict(input=prompt_input)
print(output)
# Out:
# **Comparison of Resume and Job Description:**
#
# **Resume Overview:**
# - **Position:** Senior Data Scientist
# - **Experience:** 10+ years in data science, with a focus on machine learning, statistical modeling, and big data analytics.
# - **Key Achievements:**
#   - Led teams and implemented data-driven strategies generating over $50 million in revenue.
#   - Developed advanced machine learning models, optimized data pipelines, and created fraud detection systems.
#   - Proficient in SQL, Python, R, and various machine learning techniques.
#
# **Job Description Overview:**
# - **Position:** Senior Data Scientist within Volvo Group Trucks Technology.
# - **Key Responsibilities:**
#   - Collaborate in agile teams to develop data-driven powertrain solutions.
#   - Understand customer usage and performance, providing solutions throughout the product lifecycle.
#   - Make predictions and recommendations from data to support powertrain development.
# - **Required Skills:**
#   - Strong experience in data engineering and analysis, knowledge of control systems, and data modeling (regression, clustering, neural networks, time series).
#   - Proficiency in Python (including libraries like NumPy, SciPy, Pandas, TensorFlow), R, SQL, and experience with Azure, Hadoop, and MATLAB/Simulink.
#   - Experience with relational databases, data privacy, IoT instrumentation design, and data visualization tools (Power BI, QlikView, Tableau).
#
# **Matching Analysis:**
#
# 1. **Experience:**
#    - The candidate has over 10 years of experience in data science, which aligns with the job requirement for strong experience in data engineering and analysis.
#    - The job description emphasizes a focus on powertrain engineering and control systems, which is not explicitly mentioned in the resume.
#
# 2. **Technical Skills:**
#    - The candidate is proficient in Python, R, and SQL, which matches the job requirements. However, the job description specifies the need for experience with specific libraries (NumPy, SciPy, Pandas, TensorFlow) and tools (Azure, Hadoop, MATLAB/Simulink) that are not mentioned in the resume.
#    - The resume lists machine learning techniques but does not explicitly mention control systems or feedback systems, which are important for the job.
#
# 3. **Data Modeling:**
#    - The candidate has experience in data modeling and machine learning, which aligns with the job's requirements for regression, clustering, and neural networks. However, the job description also emphasizes the application of these models in real-life challenges, which is not detailed in the resume.
#
# 4. **Collaboration and Agile Experience:**
#    - The resume indicates experience in leading teams and collaborating with cross-functional teams, which aligns with the job's emphasis on teamwork and agile methodologies.
#
# 5. **Domain Knowledge:**
#    - The job description requires a strong domain understanding in powertrain engineering, which is not addressed in the resume. This could be a significant gap if the candidate does not have relevant experience in this area.
#
# 6. **Data Visualization:**
#    - The job description mentions a passion for data visualization using tools like Power BI, QlikView, and Tableau, which are not mentioned in the resume.
#
# **Gaps Identified:**
# - Lack of specific experience or knowledge in powertrain engineering and control systems.
# - Absence of mention of specific libraries and tools required by the job (e.g., NumPy, SciPy, Azure, MATLAB/Simulink).
# - No reference to experience with data visualization tools mentioned in the job description.
# - The resume does not explicitly state experience in applying data modeling techniques to real-life challenges.
#
# **Conclusion:**
# While the candidate has a strong background in data science and relevant skills, there are notable gaps in domain-specific knowledge and certain technical proficiencies that may hinder alignment with the job requirements. Addressing these gaps could enhance the candidate's fit for the position.

# %% [markdown]
# ### 4. Gap Analysis wrt JD

# %%
prompt_input = gap_analysis_prompt.format(resume_content, job_description_content)
output = resume_chain.predict(input=prompt_input)
print(output)
# Out:
# **Comparison of Resume and Job Description:**
#
# **Resume Overview:**
# - **Position:** Senior Data Scientist
# - **Experience:** 10+ years in data science, focusing on machine learning, statistical modeling, and big data analytics.
# - **Key Achievements:**
#   - Led teams and implemented data-driven strategies generating over $50 million in revenue.
#   - Developed advanced machine learning models, optimized data pipelines, and created fraud detection systems.
#   - Proficient in SQL, Python, R, and various machine learning techniques.
#
# **Job Description Overview:**
# - **Position:** Senior Data Scientist within Volvo Group Trucks Technology.
# - **Key Responsibilities:**
#   - Collaborate in agile teams to develop data-driven powertrain solutions.
#   - Understand customer usage and performance, providing solutions throughout the product lifecycle.
#   - Make predictions and recommendations from data to support powertrain development.
# - **Required Skills:**
#   - Strong experience in data engineering and analysis, knowledge of control systems, and data modeling (regression, clustering, neural networks, time series).
#   - Proficiency in Python (including libraries like NumPy, SciPy, Pandas, TensorFlow), R, SQL, and experience with Azure, Hadoop, and MATLAB/Simulink.
#   - Experience with relational databases, data privacy, IoT instrumentation design, and data visualization tools (Power BI, QlikView, Tableau).
#
# **Identified Gaps and Mismatches:**
#
# 1. **Domain Knowledge in Powertrain Engineering:**
#    - **Gap:** The resume does not mention any experience or knowledge in powertrain engineering, which is crucial for the job.
#    - **Example to Fulfill Gap:** The candidate could take online courses or certifications related to powertrain systems, automotive engineering, or related fields to gain foundational knowledge.
#
# 2. **Control Systems and Feedback Systems:**
#    - **Gap:** The job description emphasizes knowledge of control systems and feedback systems, which is not addressed in the resume.
#    - **Example to Fulfill Gap:** The candidate could pursue training or coursework in control systems engineering to understand the principles and applications relevant to the role.
#
# 3. **Specific Libraries and Tools:**
#    - **Gap:** The job description specifies the need for experience with libraries such as NumPy, SciPy, Pandas, and TensorFlow, as well as tools like Azure, Hadoop, and MATLAB/Simulink, which are not mentioned in the resume.
#    - **Example to Fulfill Gap:** The candidate should familiarize themselves with these libraries and tools through practical projects or online tutorials, and update the resume to reflect this experience.
#
# 4. **Experience with Data Visualization Tools:**
#    - **Gap:** The job description mentions a passion for data visualization using tools like Power BI, QlikView, and Tableau, which are not included in the resume.
#    - **Example to Fulfill Gap:** The candidate could learn to use these visualization tools through online courses and apply them in projects to showcase their ability to create impactful visualizations.
#
# 5. **Experience with IoT Instrumentation Design:**
#    - **Gap:** The job description highlights the importance of understanding IoT-based instrumentation design, which is not covered in the resume.
#    - **Example to Fulfill Gap:** The candidate could engage in projects or training related to IoT systems and data logging to gain relevant experience.
#
# 6. **Agile Methodologies:**
#    - **Gap:** While the resume mentions collaboration with cross-functional teams, it does not explicitly state experience with agile methodologies.
#    - **Example to Fulfill Gap:** The candidate could participate in agile training or work on projects that utilize agile practices to gain hands-on experience.
#
# 7. **Real-Life Application of Data Modeling Techniques:**
#    - **Gap:** The job description requires experience in applying data modeling techniques to solve real-life challenges, which is not detailed in the resume.
#    - **Example to Fulfill Gap:** The candidate should provide specific examples of how they have used data modeling techniques in practical scenarios, possibly through case studies or project descriptions.
#
# **Conclusion:**
# To enhance alignment with the job requirements, the candidate should focus on gaining knowledge and experience in powertrain engineering, control systems, specific libraries and tools, data visualization, IoT instrumentation, agile methodologies, and the practical application of data modeling techniques. Updating the resume to reflect these experiences and skills will improve the candidate's fit for the position.

# %% [markdown]
# ### 5. How to improve the experience?

# %%
prompt_input = experience_enhancement_prompt.format(resume_content, job_description_content)
output = resume_chain.predict(input=prompt_input)
print(output)
# Out:
# **Practical Activities and Steps to Gain or Improve Experience Aligned with the Role:**
#
# 1. **Gain Knowledge in Powertrain Engineering:**
#    - **Action:** Enroll in online courses or workshops focused on powertrain systems, automotive engineering, or related fields. Websites like Coursera, edX, or Udacity offer relevant courses.
#    - **Recommendation:** Consider certifications such as the "Automotive Engineering" certification from SAE International or similar programs that provide foundational knowledge in automotive systems.
#
# 2. **Learn Control Systems and Feedback Systems:**
#    - **Action:** Take courses in control systems engineering, focusing on closed-loop systems and their applications in automotive technology.
#    - **Recommendation:** Look for certifications in control systems, such as the "Control Systems Engineering" course offered by various engineering institutions.
#
# 3. **Familiarize with Specific Libraries and Tools:**
#    - **Action:** Work on projects that utilize Python libraries like NumPy, SciPy, Pandas, and TensorFlow. Create small applications or data analysis projects to practice these skills.
#    - **Recommendation:** Complete a data science bootcamp or specialized training that covers these libraries in depth, such as DataCamp or Codecademy.
#
# 4. **Develop Skills in Data Visualization Tools:**
#    - **Action:** Learn to use data visualization tools like Power BI, QlikView, and Tableau. Create visualizations based on datasets to showcase your ability to turn data into insights.
#    - **Recommendation:** Obtain certifications in these tools, such as the "Tableau Desktop Specialist" or "Microsoft Certified: Data Analyst Associate" for Power BI.
#
# 5. **Understand IoT Instrumentation Design:**
#    - **Action:** Engage in projects that involve IoT systems, focusing on data logging and instrumentation design. This could include building simple IoT devices or simulations.
#    - **Recommendation:** Consider certifications in IoT, such as the "IoT Foundations" certification from Cisco or similar programs that cover IoT concepts and applications.
#
# 6. **Experience with Agile Methodologies:**
#    - **Action:** Participate in agile training workshops or join a local agile community to understand agile practices better. Engage in projects that use agile methodologies.
#    - **Recommendation:** Obtain a certification such as "Certified ScrumMaster (CSM)" or "Agile Certified Practitioner (PMI-ACP)" to formalize your understanding of agile practices.
#
# 7. **Apply Data Modeling Techniques to Real-Life Challenges:**
#    - **Action:** Work on case studies or real-world projects that require the application of data modeling techniques (regression, clustering, neural networks, time series) to solve specific problems.
#    - **Recommendation:** Participate in hackathons or data science competitions on platforms like Kaggle to gain practical experience in applying these techniques.
#
# 8. **Enhance Programming Skills:**
#    - **Action:** Improve proficiency in programming languages relevant to the role, such as Python, R, and SQL. Work on projects that require the integration of these languages.
#    - **Recommendation:** Consider certifications in Python (e.g., "Python for Data Science" from IBM) or SQL (e.g., "SQL Fundamentals" from DataCamp) to validate your skills.
#
# **Conclusion:**
# By actively pursuing these practical activities and obtaining relevant certifications, the candidate can bridge the gaps identified in their experience and align more closely with the requirements of the role within the Volvo Group Trucks Technology team. This proactive approach will enhance their qualifications and improve their chances of success in securing the position.

# %% [markdown]
# ### 6. Resume Reformatting

# %%
prompt_input = resume_formatting_prompt.format(resume_content, job_description_content)
output = resume_chain.predict(input=prompt_input)
print(output)
# Out:
# **Guidance on Enhancing the Formatting of the Resume:**
#
# 1. **Consistent Formatting:**
#    - Ensure consistent font styles and sizes throughout the resume. Use a professional font such as Arial, Calibri, or Times New Roman in a size between 10-12 points for body text and slightly larger (14-16 points) for headings.
#    - Maintain uniform spacing between sections and bullet points to create a clean and organized look.
#
# 2. **Clear Section Headings:**
#    - Use bold or slightly larger font sizes for section headings (e.g., "Professional Experience," "Education," "Skills") to make them stand out.
#    - Consider using a horizontal line or additional spacing to separate sections clearly.
#
# 3. **Bullet Points for Achievements:**
#    - Use bullet points consistently to list achievements and responsibilities. This improves readability and allows hiring managers to quickly scan for key information.
#    - Start each bullet point with strong action verbs (e.g., "Led," "Developed," "Optimized") to convey impact.
#
# 4. **Alignment and Margins:**
#    - Ensure that all text is left-aligned for a clean and professional appearance. Avoid excessive indentation or alignment issues.
#    - Use standard margins (1 inch on all sides) to ensure the content is well-framed on the page.
#
# 5. **Whitespace Utilization:**
#    - Incorporate whitespace effectively to avoid clutter. This can be achieved by adding space between sections and ensuring that bullet points are not crammed together.
#    - Avoid long paragraphs; instead, break them into concise bullet points for easier reading.
#
# 6. **Contact Information:**
#    - Place contact information at the top of the resume in a single line or in a compact format. Include the name, email, phone number, and location (city and state) without excessive spacing.
#    - Consider using a slightly larger font for the name to make it more prominent.
#
# 7. **Education Section:**
#    - Format the education section to include the degree, major, institution name, and graduation date clearly. For example:
#      ```
#      Master of Science in Data Science
#      New York University, New York, NY
#      May 20xx
#      ```
#
# 8. **Skills Section:**
#    - Organize the skills section into categories (e.g., "Machine Learning," "Statistical Modeling," "Programming Languages") to make it easier for hiring managers to identify relevant skills.
#    - Use bullet points or a simple list format to present skills clearly.
#
# 9. **Visual Elements:**
#    - Consider adding subtle visual elements, such as a professional color scheme (e.g., navy blue or dark green) for headings or lines, to enhance visual appeal without being distracting.
#    - Avoid excessive graphics or images that may detract from the content.
#
# 10. **Proofreading:**
#     - Carefully proofread the resume for any spelling or grammatical errors. Ensure that all information is accurate and up-to-date.
#     - Consider having a peer or mentor review the resume for additional feedback on formatting and content.
#
# **Conclusion:**
# By implementing these formatting enhancements, the candidate can create a visually appealing and easy-to-read resume that effectively showcases their skills and experience. A well-structured resume will help capture the attention of hiring managers and improve the chances of securing an interview.

# %% [markdown]
# ### 7. Resume Length Analysis

# %%
prompt_input = resume_length_prompt.format(resume_content, job_description_content)
output = resume_chain.predict(input=prompt_input)
print(output)
# Out:
# **Strategies for Adjusting the Length of the Resume:**
#
# 1. **Prioritize Relevant Experience:**
#    - **Action:** Focus on including only the most relevant work experiences that align with the job description. For instance, emphasize roles and achievements that demonstrate skills in data engineering, control systems, and predictive analysis.
#    - **Recommendation:** Remove or condense less relevant positions or details that do not directly contribute to the candidate's fit for the role at Volvo Group.
#
# 2. **Use Concise Language:**
#    - **Action:** Rewrite bullet points to be more concise. Aim for clarity and brevity by eliminating unnecessary words while retaining key achievements and responsibilities.
#    - **Example:** Instead of "Led a team of 8 data scientists in developing and implementing advanced machine learning models, resulting in a 25% increase in predictive accuracy," consider "Led a team of 8 in developing machine learning models, increasing predictive accuracy by 25%."
#
# 3. **Limit Bullet Points:**
#    - **Action:** Reduce the number of bullet points under each job title to the most impactful ones. Aim for 3-5 bullet points that highlight significant achievements.
#    - **Recommendation:** Focus on quantifiable results and unique contributions that showcase the candidate's skills and impact.
#
# 4. **Combine Similar Experiences:**
#    - **Action:** If the candidate has held multiple similar roles, consider combining them into one section to avoid redundancy.
#    - **Example:** If the candidate has worked in different data science roles that involved similar tasks, summarize them under a single heading with a few key achievements.
#
# 5. **Streamline the Skills Section:**
#    - **Action:** Instead of listing every skill, categorize them and focus on the most relevant ones for the job description.
#    - **Recommendation:** For example, group programming languages and tools together and highlight only those that are specifically mentioned in the job description (e.g., Python, SQL, and relevant libraries).
#
# 6. **Remove Outdated or Irrelevant Information:**
#    - **Action:** Eliminate any outdated skills or experiences that do not add value to the current job application.
#    - **Recommendation:** If the candidate has skills or experiences that are not relevant to the role at Volvo Group, consider removing them to keep the resume focused.
#
# 7. **Adjust Formatting:**
#    - **Action:** Use formatting techniques to save space, such as reducing line spacing or margins slightly, while ensuring the resume remains readable.
#    - **Recommendation:** Ensure that the resume fits on one page if possible, especially for candidates with less than 15 years of experience.
#
# 8. **Focus on Education:**
#    - **Action:** Keep the education section concise. Include only the degree, major, institution, and graduation date.
#    - **Recommendation:** If the candidate has additional certifications or training, consider listing them in a separate section or only including the most relevant ones.
#
# 9. **Utilize a Summary Statement:**
#    - **Action:** Replace the lengthy introductory paragraph with a brief summary statement that encapsulates the candidate's experience and skills in 2-3 sentences.
#    - **Example:** "Senior Data Scientist with 10+ years of experience in machine learning and data analytics, proven track record in driving revenue growth through data-driven strategies."
#
# 10. **Seek Feedback:**
#     - **Action:** Have peers or mentors review the resume to identify areas where content can be trimmed or made more concise.
#     - **Recommendation:** Fresh eyes can often spot redundancies or areas for improvement that the candidate may overlook.
#
# **Conclusion:**
# By implementing these strategies, the candidate can create a more concise and focused resume that effectively highlights their qualifications for the role at Volvo Group. A well-structured, shorter resume will enhance readability and increase the chances of capturing the attention of hiring managers.
