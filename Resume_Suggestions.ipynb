# %%
import os

from langchain.chains import ConversationChain
from langchain_core.messages import SystemMessage
from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate
from langchain.memory import ConversationBufferWindowMemory
from langchain_openai import ChatOpenAI

# %%
OPENAI_API_KEY = "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"
os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY
model_name = "gpt-4o-mini-2024-07-18"

# %%
template_content = """You are a helpful assistant. You do not respond as 'User' or pretend to be 'User'. You only 
respond once as 'assistant'. 

System Role: Resume Coach

Your role is to act as a resume coach. You will assist users in improving their resumes to better align with specific 
job descriptions. Provide professional advice on resume building, interview preparation, and career development. 
Offer constructive feedback and encouragement. Whenever you are given a resume and a job description, there will be 
tokens added before and after the resume and job description. The tokens are as follows: <RESUME STARTS HERE> and 
<RESUME ENDS HERE> for the resume and <JOB DESCRIPTION STARTS HERE> and <JOB DESCRIPTION ENDS HERE> for the job 
description. Utilize these tokens to provide feedback and suggestions and clearly segregate the resume and job
description. Do not mix up the content of the resume and job description. In case the resume or job requirements 
in the description do not align with each other, do not mix up the content of the resume and job description and 
keep them separate and process them accordingly. Provide feedback based only on the content provided.
"""

resume_analysis_prompt = "Provide a detailed summary of the candidate's skills, experience, and qualifications based on the content of the following resume: <RESUME STARTS HERE> {}. <RESUME ENDS HERE>"
job_description_analysis_prompt = "List the key skills, qualifications, and experience required as outlined in the following job description: <JOB DESCRIPTION STARTS HERE> {}. <JOB DESCRIPTION ENDS HERE>"
comparison_prompt = "Compare the resume: <RESUME STARTS HERE> {}. <RESUME ENDS HERE> with the job description: <JOB DESCRIPTION STARTS HERE> {}.<JOB DESCRIPTION ENDS HERE> Do they match? If not, what are the gaps? Do not make any assumptions about the candidate's skills or experience or the job requirements."
gap_analysis_prompt = "Compare the skills and experience detailed in this resume: <RESUME STARTS HERE> {} <RESUME ENDS HERE> with the requirements listed in the job description: <JOB DESCRIPTION STARTS HERE> {}. <JOB DESCRIPTION ENDS HERE> Identify any gaps or mismatches and list them out specificly. Please provide examples on how to fulfill those gaps."
experience_enhancement_prompt = "Based on the candidate's experience outlined in this resume: <RESUME STARTS HERE> {} <RESUME ENDS HERE>, recommend practical activities or steps to gain or improve the experience aligned with the needs of this role: <JOB DESCRIPTION STARTS HERE> {}. <JOB DESCRIPTION ENDS HERE>. Include recommendations for additional qualifications or certifications."
resume_formatting_prompt = "Offer guidance on how the candidate can enhance the formatting of their resume: <RESUME STARTS HERE> {} <RESUME ENDS HERE> to improve visual appeal and readability."
resume_length_prompt = "Recommend strategies for the candidate to adjust the length of their resume: <RESUME STARTS HERE> {} <RESUME ENDS HERE>, ensuring it is concise while remaining aligned with the requirements in the job description: <JOB DESCRIPTION STARTS HERE> {}. <JOB DESCRIPTION ENDS HERE>"

# %%
def generate_llm_response(prompt_input):
    output = resume_chain.predict(input=prompt_input)
    return output

# %%
system_message = SystemMessage(content=template_content)
human_message = HumanMessagePromptTemplate.from_template("{history} User:{input} Assistant:")

prompt_template = ChatPromptTemplate(messages=[system_message, human_message], validate_template=True)

memory = ConversationBufferWindowMemory(k=3)

# %% [markdown]
# ### Chain of Thought(COT) Prompting

# %%
cot_chain = ConversationChain(
        llm=ChatOpenAI(temperature=0.0, model="gpt-3.5-turbo-1106"),
        verbose=False
)

# %% [markdown]
# <hr>

# %% [markdown]
# ### Resume Analysis

# %%
llm = ChatOpenAI(temperature=0.0, model=model_name)

# %%
resume_chain = ConversationChain(
        llm=llm,
        prompt=prompt_template,
        memory=memory,
        verbose=False
)

# %%
resume_content = """
senior data scientist  \nexample by resume genius  \nchicago, il  •  your.email @email.com •  ( 312) 875-3382  
\n \naccomplished senior data scientist with 10+ years of experience driving innovative solutions and delivering 
\nactionable insights. expertise in machine learning, statistical modeling, and big data analytics. 
proven track record of \nleading cross -functional te ams and implementing data -driven strategies that have 
generated $50m+ in revenue.  \nprofessional experience  \n \nsenior data scientist  \nhargrove tech , chicago, 
il  \naugust 20 xx–present  \n lead a team of 8 data scientists in developing and implementing advanced machine 
learning models, resulting \nin a 25% increase in predictive accuracy  \n spearheaded a company -wide initiative
to optimize data pipelines, reducing processing time by 40% and \nsaving $1.2m annually  \n collaborate with
cross -functional teams to develop data -driven strategies, contributing to a 15% increase in \noverall revenue 
\nlead data scientist  \nsuntrust analytics , chicago, il  \njuly 20 xx–august 20 xx \n developed and deployed 
a real -time fraud detection system using ensemble learning techniques, saving the \ncompany $3.5m in potential 
losses  \n built and maintained a customer segmentation model using clustering algorithms, resulting in a 20% 
increase \nin targeted marketing roi  \n conducted regular workshops and training sessions on advanced 
data science techniques, upskilling the team \nand improving overall performance by 30%  \ndata analyst  
\nmaverick solutions, new york, ny  \njuly 20 xx–august 20 xx \n analyzed large datasets using sql and 
python, providing actionable insights to business stakeholders  \n developed and maintained etl processes, 
ensuring timely and accurate data integration from multiple \nsources  \n created ad -hoc reports and analyses, 
contributing to data -driven decision making  \neducation  \n \nnew york university , new york, ny  \nms in data science  \nmay 20xx  \nadditional skills  \n \n● machine learning:  supervised learning, unsupervised learning, deep learning, neural networks, \nensemble methods, natural language processing (nlp)  \n● statistical modeling:  regression analysis, time series analysis, bayesian inference, hypothesis \ntesting, experimental design  \n● programming languages:  python, r, sql, java, scala  \n \n  \n \ndear job seeker,  \n \nif you’re looking for a classy resume template, you can’t do any better than \nthe “milano”. its simple elegance is just what you need if you want to imbue \nyour resume with a balance of professionalism and good taste — plus a \ndash of creativity.  \n \neverything on the milano is left -aligned, which helps the hiring manager \nquickly look through your resume by simply scanning down the page to \nidentify relevant experience and skills.  \n \nif you’re still struggling to write your resume, here are some free resources \nto help you put together a resume that shows employers you’re the right \nperson for the job:  \n \n·     free resume builder  \n·     how to write a resume  \n·     resume samples by industry  \n \nonce you have a great resume, pair it with a convincing cover letter using \nour matching  2022 cover letter template . here are a few resources to help \nyou write a cover letter that gives your application the boost it needs to \nland you an interview:  \n·     cover letter builder  \n·     how to write a cover letter  \n·     cover letter examples by industry  \n \n \n \nbest regards,  \n \n \n \n \n \n \n \nimportant:  to delete the second page, right -click on the page and click “delete rows”
"""

# %%
job_description_content="""
what do we do? \n\nwe are the simulation and analytics team within volvo group trucks technology, a dynamic team working towards enabling the technology organization in evaluating futuristic products and services for volvo business units such as trucks, buses, construction equipment and marine\n\nthe main tasks in our team are to meet our customer’s expectation on quality, fuel consumption and to comply with emission legislation. this is done by selecting engine hw-components and calibrate engine related functions. upcoming emission legislation requires development of advanced control strategies together with an optimized hardware and software. you will be an important contributor in this development. powertrain is the heart of the truck and is one of the focus areas within volvo group, which is at the forefront of sustainable transport solutions for tomorrow.\n\nwhat will you do? \nyou will work in agile teams through good collaboration with our colleagues in software development and design teams all around the world.\n\nyou along with the team will be responsible for understanding customer usage and performance of our products and for providing our solutions throughout entire product life cycle, from idea investigation and concept evaluation to industrialization and to aftermarket and maintenance. you will make meaningful interpretations, recommendations and eventually predictions from the data available from various sources to support our endeavor in moving towards data driven powertrain development\n\nyou get the opportunity to follow your data driven models from script to test cell to verification in a truck and eventually to being used by our end customers.\n\nwe have an agile way of working, where each team plan their activities in sprints and deliver solutions together as a team. we strive to have an open and honest environment within the teams, where it is easy to ask each other for support when needed. the tasks can be either part of a larger project or short tasks to improve products currently in production.\n\nyou will get the opportunity to interact with highly committed colleagues from different cultures. we hope you will learn as much from us as we will from you.\n\n who are you? \n\nwe believe that to be successful in this position, you are a team player, have strong experience in data engineering and analysis area, and a will to deliver. you have a knowledge of control systems and feedback systems (closed loop) in general with an exposure to numerical and data driven simulation of a system. you must have a proven experience in data modelling – regression, clustering, neural networks, time series etc. and should have used them in solving real-life challenges (prediction, automation, real time optimization etc).\n\nyou have a willingness to learn and take more responsibility with can-do attitude.\n\nyou will be greatly appreciated in this role if you have demonstrated predictive analysis and decision-making using data.\n\nif you are a master’s degree holder in mechanical/automobile/electronics/mechatronics engineering with fantastic analytical skills, have gained a strong domain understanding in powertrain engineering with proven skills in handling and analysing large set of data to make meaningful interpretations and if you believe that you can work smoothly with python ( including libraries like numpy, scipy, pandas, tensorflow) , r, sql, git, azure, hadoop and matlab/simulink, pyspark, c/c++/ scala then you can be a good fit into this role.\n\nexperience of working with relational databases, data privacy and understanding of iot based instrumentation design with additional data logging to build or validate models is a big plus.\n\na passion for turning data into knowledge with great visualizations using power bi, qlikview, tableau and an experience of working with plant/ component models, and integration of these models into sil/mil/hil evaluations would be an icing on the cake.
"""

# %% [markdown]
# ### 1. Resume Analysis

# %%
prompt_input = resume_analysis_prompt.format(resume_content, job_description_content)
output = resume_chain.predict(input=prompt_input)
print(output)
# Out:
# **Candidate Summary:**
#
# The candidate is an accomplished Senior Data Scientist with over 10 years of experience in the field, demonstrating a strong ability to drive innovative solutions and deliver actionable insights. They possess expertise in machine learning, statistical modeling, and big data analytics, with a proven track record of leading cross-functional teams and implementing data-driven strategies that have generated over $50 million in revenue.
#
# **Professional Experience:**
#
# 1. **Senior Data Scientist at Hargrove Tech (Current Position)**
#    - Leads a team of 8 data scientists in developing advanced machine learning models, achieving a 25% increase in predictive accuracy.
#    - Spearheaded an initiative to optimize data pipelines, resulting in a 40% reduction in processing time and annual savings of $1.2 million.
#    - Collaborates with cross-functional teams to develop strategies that contributed to a 15% increase in overall revenue.
#
# 2. **Lead Data Scientist at SunTrust Analytics**
#    - Developed and deployed a real-time fraud detection system using ensemble learning techniques, saving the company $3.5 million in potential losses.
#    - Built and maintained a customer segmentation model using clustering algorithms, leading to a 20% increase in targeted marketing ROI.
#    - Conducted workshops and training sessions on advanced data science techniques, enhancing team performance by 30%.
#
# 3. **Data Analyst at Maverick Solutions**
#    - Analyzed large datasets using SQL and Python, providing actionable insights to business stakeholders.
#    - Developed and maintained ETL processes for timely and accurate data integration from multiple sources.
#    - Created ad-hoc reports and analyses to support data-driven decision-making.
#
# **Education:**
# - Master of Science in Data Science from New York University.
#
# **Additional Skills:**
# - **Machine Learning:** Proficient in supervised and unsupervised learning, deep learning, neural networks, ensemble methods, and natural language processing (NLP).
# - **Statistical Modeling:** Experienced in regression analysis, time series analysis, Bayesian inference, hypothesis testing, and experimental design.
# - **Programming Languages:** Skilled in Python, R, SQL, Java, and Scala.
#
# Overall, the candidate showcases a robust combination of technical skills, leadership experience, and a strong educational background, making them a highly qualified candidate for senior data science roles.

# %% [markdown]
# ### 2. Job Description Analysis

# %%
prompt_input = job_description_analysis_prompt.format(resume_content, job_description_content)
output = resume_chain.predict(input=prompt_input)
print(output)
# Out:
# **Key Skills, Qualifications, and Experience Required:**
#
# 1. **Experience:**
#    - 10+ years of experience as a Senior Data Scientist.
#    - Proven track record of driving innovative solutions and delivering actionable insights.
#    - Experience leading cross-functional teams and implementing data-driven strategies that have generated over $50 million in revenue.
#
# 2. **Technical Skills:**
#    - Expertise in machine learning, including supervised learning, unsupervised learning, deep learning, neural networks, ensemble methods, and natural language processing (NLP).
#    - Proficient in statistical modeling techniques such as regression analysis, time series analysis, Bayesian inference, hypothesis testing, and experimental design.
#    - Strong programming skills in Python, R, SQL, Java, and Scala.
#
# 3. **Professional Experience:**
#    - Experience leading teams in developing and implementing advanced machine learning models, with a focus on improving predictive accuracy.
#    - Ability to spearhead initiatives to optimize data pipelines, resulting in significant reductions in processing time and cost savings.
#    - Experience collaborating with cross-functional teams to develop data-driven strategies that enhance overall revenue.
#
# 4. **Project Management:**
#    - Experience in developing and deploying real-time systems, such as fraud detection systems, and maintaining customer segmentation models.
#    - Ability to conduct workshops and training sessions to upskill team members and improve overall performance.
#
# 5. **Education:**
#    - Master’s degree in Data Science or a related field from a recognized institution.
#
# Overall, the job description emphasizes a blend of extensive experience, technical expertise, leadership capabilities, and a strong educational background in data science.

# %% [markdown]
# ### 3. Resume Comparison with JD

# %%
prompt_input = comparison_prompt.format(resume_content, job_description_content)
output = resume_chain.predict(input=prompt_input)
print(output)
# Out:
# **Comparison of Resume and Job Description:**
#
# **1. Experience:**
#    - **Resume:** The candidate has over 10 years of experience as a Senior Data Scientist, with a proven track record of leading teams and implementing data-driven strategies.
#    - **Job Description:** The role requires strong experience in data engineering and analysis, with a focus on predictive analysis and decision-making using data. It also emphasizes a background in powertrain engineering.
#
#    **Gap:** The resume does not explicitly mention experience in powertrain engineering or related fields, which is a key requirement in the job description.
#
# **2. Technical Skills:**
#    - **Resume:** The candidate has expertise in machine learning, statistical modeling, and programming languages such as Python, R, SQL, Java, and Scala.
#    - **Job Description:** The role requires knowledge of control systems, data modeling (regression, clustering, neural networks, time series), and proficiency in Python (including libraries like NumPy, SciPy, Pandas, TensorFlow), R, SQL, and additional tools like Azure, Hadoop, and MATLAB/Simulink.
#
#    **Gap:** While the candidate has strong programming skills, the resume does not mention specific experience with control systems, feedback systems, or the additional tools and libraries listed in the job description (e.g., Azure, Hadoop, MATLAB/Simulink).
#
# **3. Project Management and Collaboration:**
#    - **Resume:** The candidate has experience leading teams and collaborating with cross-functional teams to develop data-driven strategies.
#    - **Job Description:** The role emphasizes working in agile teams and collaborating with software development and design teams globally.
#
#    **Match:** The candidate's experience in leading teams and collaboration aligns well with the job's requirements for teamwork and agile methodologies.
#
# **4. Education:**
#    - **Resume:** The candidate holds a Master’s degree in Data Science.
#    - **Job Description:** The role prefers a Master’s degree in mechanical/automobile/electronics/mechatronics engineering.
#
#    **Gap:** The candidate's educational background in Data Science does not match the preferred fields of study outlined in the job description.
#
# **5. Data Visualization and Interpretation:**
#    - **Resume:** The candidate has experience in analyzing large datasets and providing actionable insights.
#    - **Job Description:** The role values a passion for turning data into knowledge with great visualizations using tools like Power BI, QlikView, or Tableau.
#
#    **Gap:** The resume does not mention experience with specific data visualization tools, which is highlighted as important in the job description.
#
# **Conclusion:**
# While the candidate has a strong background in data science and relevant experience, there are notable gaps in specific industry knowledge (powertrain engineering), technical skills (control systems, specific libraries and tools), and educational background (preferred engineering fields). Additionally, the lack of mention of data visualization tools could be a disadvantage for this particular role. To improve alignment, the candidate may need to emphasize any relevant experience or skills that relate to the automotive or powertrain industry, as well as any familiarity with the specific tools and technologies mentioned in the job description.

# %% [markdown]
# ### 4. Gap Analysis wrt JD

# %%
prompt_input = gap_analysis_prompt.format(resume_content, job_description_content)
output = resume_chain.predict(input=prompt_input)
print(output)
# Out:
# **Gaps and Mismatches Between Resume and Job Description:**
#
# 1. **Industry-Specific Experience:**
#    - **Gap:** The resume does not mention any experience in the powertrain engineering or automotive industry, which is a key focus of the job description.
#    - **Example to Fulfill Gap:** The candidate could seek opportunities to work on projects related to automotive or powertrain systems, or highlight any relevant projects or coursework from their education that may relate to this field.
#
# 2. **Control Systems Knowledge:**
#    - **Gap:** The job description emphasizes knowledge of control systems and feedback systems (closed loop), which is not mentioned in the resume.
#    - **Example to Fulfill Gap:** The candidate could take online courses or certifications in control systems and feedback mechanisms to gain foundational knowledge and then include this in their resume.
#
# 3. **Data Engineering and Analysis:**
#    - **Gap:** The job description requires strong experience in data engineering and analysis, particularly in the context of numerical and data-driven simulation, which is not explicitly detailed in the resume.
#    - **Example to Fulfill Gap:** The candidate could work on projects that involve data engineering tasks, such as building data pipelines or working with simulation data, and document these experiences in their resume.
#
# 4. **Specific Technical Skills:**
#    - **Gap:** The job description mentions specific tools and libraries (e.g., NumPy, SciPy, Pandas, TensorFlow, Azure, Hadoop, MATLAB/Simulink) that are not listed in the resume.
#    - **Example to Fulfill Gap:** The candidate could gain proficiency in these tools through online courses or practical projects and then update their resume to reflect this experience.
#
# 5. **Data Visualization Tools:**
#    - **Gap:** The job description highlights a passion for data visualization using tools like Power BI, QlikView, or Tableau, which are not mentioned in the resume.
#    - **Example to Fulfill Gap:** The candidate could learn to use one or more of these visualization tools and create sample dashboards or reports to showcase their skills, then include this experience in their resume.
#
# 6. **Educational Background:**
#    - **Gap:** The job description prefers a Master’s degree in mechanical, automobile, electronics, or mechatronics engineering, while the candidate has a Master’s in Data Science.
#    - **Example to Fulfill Gap:** The candidate could consider pursuing additional coursework or certifications in mechanical or automotive engineering to strengthen their qualifications for this specific role.
#
# 7. **Experience with IoT and Instrumentation Design:**
#    - **Gap:** The job description mentions a preference for experience with IoT-based instrumentation design and data logging, which is not addressed in the resume.
#    - **Example to Fulfill Gap:** The candidate could seek projects or internships that involve IoT applications or instrumentation, and document any relevant experience in their resume.
#
# 8. **Agile Methodologies:**
#    - **Gap:** While the resume mentions collaboration with cross-functional teams, it does not explicitly state experience with agile methodologies, which is emphasized in the job description.
#    - **Example to Fulfill Gap:** The candidate could participate in agile projects or training sessions to gain experience and then highlight this in their resume.
#
# **Conclusion:**
# To improve alignment with the job description, the candidate should focus on gaining relevant experience in the automotive or powertrain industry, enhance their technical skills with specific tools and methodologies mentioned, and consider additional education or certifications that align with the job requirements. By addressing these gaps, the candidate can strengthen their application for the role.

# %% [markdown]
# ### 5. How to improve the experience?

# %%
prompt_input = experience_enhancement_prompt.format(resume_content, job_description_content)
output = resume_chain.predict(input=prompt_input)
print(output)
# Out:
# **Practical Activities and Steps to Gain or Improve Experience Aligned with the Role:**
#
# 1. **Gain Industry-Specific Experience:**
#    - **Action:** Seek internships or project opportunities within the automotive or powertrain engineering sectors. This could involve working with companies that focus on engine calibration, emissions testing, or vehicle performance analysis.
#    - **Recommendation:** Attend industry conferences or workshops related to automotive technology to network and learn about current trends and challenges.
#
# 2. **Develop Knowledge of Control Systems:**
#    - **Action:** Enroll in online courses or workshops that focus on control systems and feedback mechanisms. Websites like Coursera, edX, or Udacity offer relevant courses.
#    - **Recommendation:** Consider obtaining a certification in control systems engineering, which can provide a formal acknowledgment of your skills in this area.
#
# 3. **Enhance Data Engineering Skills:**
#    - **Action:** Work on personal or open-source projects that involve building data pipelines, data integration, and simulation of systems. This could include using tools like Apache Spark or Hadoop.
#    - **Recommendation:** Take a course in data engineering or big data technologies to solidify your understanding and practical skills.
#
# 4. **Familiarize with Specific Technical Tools:**
#    - **Action:** Learn to use libraries and tools mentioned in the job description, such as NumPy, SciPy, Pandas, TensorFlow, Azure, and MATLAB/Simulink. Create small projects that utilize these tools to demonstrate your proficiency.
#    - **Recommendation:** Obtain certifications in relevant tools, such as Microsoft Azure Data Scientist Associate or MATLAB certifications, to validate your skills.
#
# 5. **Improve Data Visualization Skills:**
#    - **Action:** Practice using data visualization tools like Power BI, QlikView, or Tableau. Create dashboards or reports based on datasets available online (e.g., Kaggle).
#    - **Recommendation:** Consider taking a course in data visualization to learn best practices and advanced techniques.
#
# 6. **Engage in Agile Methodologies:**
#    - **Action:** Participate in agile projects, either in your current job or through volunteer opportunities. Familiarize yourself with tools like Jira or Trello for project management.
#    - **Recommendation:** Attend workshops or training sessions on agile methodologies to understand the principles and practices better.
#
# 7. **Pursue Relevant Education:**
#    - **Action:** If feasible, consider pursuing additional coursework or a certification in mechanical, automobile, electronics, or mechatronics engineering to align your educational background with the job requirements.
#    - **Recommendation:** Look for online programs or local universities that offer relevant courses or certifications.
#
# 8. **Explore IoT and Instrumentation Design:**
#    - **Action:** Work on projects that involve IoT applications, such as building a simple IoT device that collects and analyzes data. This could involve using platforms like Arduino or Raspberry Pi.
#    - **Recommendation:** Take a course in IoT systems or instrumentation design to gain a deeper understanding of how these systems work.
#
# 9. **Build a Portfolio:**
#    - **Action:** Create a portfolio showcasing your projects, particularly those related to data modeling, control systems, and data visualization. Include case studies that demonstrate your problem-solving skills and the impact of your work.
#    - **Recommendation:** Use platforms like GitHub to share your code and projects, making it easier for potential employers to see your skills in action.
#
# By actively pursuing these activities and recommendations, the candidate can significantly enhance their qualifications and align their experience with the needs of the role in the simulation and analytics team at Volvo Group Trucks Technology.

# %% [markdown]
# ### 6. Resume Reformatting

# %%
prompt_input = resume_formatting_prompt.format(resume_content, job_description_content)
output = resume_chain.predict(input=prompt_input)
print(output)
# Out:
# **Guidance on Enhancing the Formatting of the Resume:**
#
# 1. **Consistent Formatting:**
#    - Ensure consistent font styles and sizes throughout the resume. Use a professional font (e.g., Arial, Calibri, or Times New Roman) and maintain the same size for headings and body text.
#    - Example: Use a larger font size (e.g., 14-16 pt) for the name and section headings, and a smaller size (e.g., 10-12 pt) for the body text.
#
# 2. **Clear Section Headings:**
#    - Use bold or slightly larger font for section headings (e.g., "Professional Experience," "Education," "Skills") to make them stand out.
#    - Example: Change "professional experience" to "Professional Experience" and make it bold.
#
# 3. **Bullet Points for Clarity:**
#    - Use bullet points to list responsibilities and achievements under each job title. This improves readability and allows hiring managers to quickly scan for relevant information.
#    - Example: Instead of writing in paragraph form, use bullet points for each achievement, such as:
#      - Led a team of 8 data scientists in developing advanced machine learning models, resulting in a 25% increase in predictive accuracy.
#      - Spearheaded a company-wide initiative to optimize data pipelines, reducing processing time by 40% and saving $1.2M annually.
#
# 4. **Alignment and Spacing:**
#    - Ensure that all text is left-aligned for a clean and professional look. Maintain consistent spacing between sections and bullet points to avoid clutter.
#    - Example: Add extra space between sections (e.g., 10-12 points) to create a clear separation.
#
# 5. **Contact Information:**
#    - Place the contact information at the top of the resume in a single line or in a compact format. Ensure it is easy to find.
#    - Example:
#      ```
#      John Doe | Chicago, IL | your.email@email.com | (312) 875-3382
#      ```
#
# 6. **Education Section:**
#    - Format the education section to include the degree, major, institution, and graduation date clearly. Consider using italics for the institution name.
#    - Example:
#      ```
#      Education
#      MS in Data Science, New York University, New York, NY, May 20xx
#      ```
#
# 7. **Skills Section:**
#    - Organize the skills section into categories (e.g., "Machine Learning," "Statistical Modeling," "Programming Languages") to make it easier for hiring managers to identify relevant skills.
#    - Example:
#      ```
#      Additional Skills
#      - Machine Learning: Supervised Learning, Unsupervised Learning, Deep Learning
#      - Statistical Modeling: Regression Analysis, Time Series Analysis
#      - Programming Languages: Python, R, SQL, Java, Scala
#      ```
#
# 8. **Visual Elements:**
#    - Consider adding subtle visual elements, such as lines or borders, to separate sections. However, keep it minimal to maintain professionalism.
#    - Example: A thin line under the section headings can help delineate sections without being distracting.
#
# 9. **Length and Conciseness:**
#    - Aim to keep the resume to one or two pages, focusing on the most relevant experience and skills. Remove any unnecessary filler content.
#    - Example: If the resume exceeds two pages, prioritize the most impactful experiences and achievements.
#
# 10. **Proofreading:**
#     - Ensure there are no spelling or grammatical errors. A clean, error-free resume reflects attention to detail.
#     - Example: Use tools like Grammarly or have a peer review the resume for any mistakes.
#
# By implementing these formatting enhancements, the candidate can create a visually appealing and easy-to-read resume that effectively showcases their qualifications and experience.

# %% [markdown]
# ### 7. Resume Length Analysis

# %%
prompt_input = resume_length_prompt.format(resume_content, job_description_content)
output = resume_chain.predict(input=prompt_input)
print(output)
# Out:
# **Strategies for Adjusting the Length of the Resume:**
#
# 1. **Prioritize Relevant Experience:**
#    - **Action:** Focus on including only the most relevant work experiences that align with the job description. Remove or condense experiences that do not directly relate to the role in the simulation and analytics team.
#    - **Example:** If the candidate has multiple roles that are similar, they can combine them into one entry or summarize the less relevant tasks.
#
# 2. **Use Concise Language:**
#    - **Action:** Rewrite bullet points to be more concise while still conveying the impact of the work. Avoid unnecessary words and jargon.
#    - **Example:** Instead of "collaborate with cross-functional teams to develop data-driven strategies, contributing to a 15% increase in overall revenue," consider "Collaborated with cross-functional teams to enhance data strategies, boosting revenue by 15%."
#
# 3. **Limit Bullet Points:**
#    - **Action:** For each position, limit the number of bullet points to 3-5 that highlight the most significant achievements and responsibilities.
#    - **Example:** If there are 7 bullet points under a job title, select the top 3-5 that best demonstrate skills relevant to the job description.
#
# 4. **Combine Similar Skills:**
#    - **Action:** In the skills section, group similar skills together to save space and improve readability.
#    - **Example:** Instead of listing each machine learning technique separately, group them as "Machine Learning: Supervised, Unsupervised, Deep Learning, NLP."
#
# 5. **Remove Redundant Information:**
#    - **Action:** Eliminate any repetitive information or experiences that do not add new value to the resume.
#    - **Example:** If multiple roles involved similar responsibilities, summarize them in one bullet point that captures the essence of those tasks.
#
# 6. **Adjust Formatting:**
#    - **Action:** Use formatting techniques to save space, such as reducing the font size slightly (while remaining readable) or adjusting margins.
#    - **Example:** If the resume is currently in a 1-inch margin format, consider reducing it to 0.75 inches.
#
# 7. **Focus on Impact:**
#    - **Action:** Emphasize quantifiable achievements and results rather than listing duties. This not only shortens the resume but also makes it more impactful.
#    - **Example:** Instead of saying "developed a customer segmentation model," say "Developed a customer segmentation model that increased targeted marketing ROI by 20%."
#
# 8. **Limit Education Details:**
#    - **Action:** For the education section, include only the degree, major, institution, and graduation date. Remove any additional details unless they are particularly relevant.
#    - **Example:** Instead of detailing coursework, simply state: "MS in Data Science, New York University, May 20xx."
#
# 9. **Use a Summary Statement:**
#    - **Action:** Consider replacing the lengthy introductory paragraph with a brief summary statement that encapsulates key qualifications in 2-3 sentences.
#    - **Example:** "Senior Data Scientist with 10+ years of experience in machine learning and big data analytics, proven in driving revenue growth through data-driven strategies."
#
# 10. **Review and Edit:**
#     - **Action:** After making adjustments, review the resume to ensure it flows well and maintains clarity. Consider seeking feedback from peers or using resume review services.
#     - **Example:** Use tools like Grammarly or Hemingway to check for clarity and conciseness.
#
# By implementing these strategies, the candidate can create a more concise resume that effectively highlights their qualifications while aligning with the requirements of the job description.
